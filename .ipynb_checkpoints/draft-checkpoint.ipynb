# %% [markdown]
# #   Initialisation des packages et téléchargement du jeu de données

# %% [markdown]
# ## Installation et importation des packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Vérification des packages

# %%
pip list --outdated
# Out:
# Package                       Version             Latest     Type
# ----------------------------- ------------------- ---------- -----
# anyio                         2.2.0               3.5.0      wheel
# argon2-cffi                   20.1.0              21.3.0     wheel
# astroid                       2.6.6               2.9.3      wheel
# astropy                       4.2.1               5.0.1      wheel
# async-timeout                 3.0.1               4.0.2      wheel
# attrs                         20.3.0              21.4.0     wheel
# autopep8                      1.5.6               1.6.0      wheel
# Babel                         2.9.0               2.9.1      wheel
# beautifulsoup4                4.9.3               4.10.0     wheel
# bitarray                      1.9.2               2.3.5      sdist
# black                         19.10b0             22.1.0     wheel
# bleach                        3.3.0               4.1.0      wheel
# bokeh                         2.3.2               2.4.2      wheel
# boto3                         1.17.46             1.20.46    wheel
# botocore                      1.20.109            1.23.46    wheel
# cachetools                    4.1.1               5.0.0      wheel
# category-encoders             2.2.2               2.3.0      wheel
# certifi                       2020.12.5           2021.10.8  wheel
# cffi                          1.14.5              1.15.0     wheel
# click                         7.1.2               8.0.3      wheel
# cloudpickle                   1.6.0               2.0.0      wheel
# comtypes                      1.1.9               1.1.10     sdist
# contextlib2                   0.6.0.post1         21.6.0     wheel
# cryptography                  3.4.7               36.0.1     wheel
# cycler                        0.10.0              0.11.0     wheel
# Cython                        0.29.23             0.29.27    wheel
# cytoolz                       0.11.0              0.11.2     sdist
# dask                          2.30.0              2022.1.1   wheel
# decorator                     5.0.6               5.1.1      wheel
# distributed                   2021.4.0            2022.1.1   wheel
# docutils                      0.17                0.18.1     wheel
# et-xmlfile                    1.0.1               1.1.0      wheel
# filelock                      3.0.12              3.4.2      wheel
# flake8                        3.9.0               4.0.1      wheel
# Flask                         1.1.2               2.0.2      wheel
# fsspec                        0.9.0               2022.1.0   wheel
# funcy                         1.16                1.17       wheel
# gast                          0.4.0               0.5.3      wheel
# gensim                        4.0.1               4.1.2      wheel
# gevent                        21.1.2              21.12.0    wheel
# google-api-core               1.22.2              2.4.0      wheel
# google-auth                   1.21.3              2.6.0      wheel
# google-cloud-core             1.4.3               2.2.2      wheel
# google-cloud-storage          1.31.0              2.1.0      wheel
# google-crc32c                 1.0.0               1.3.0      wheel
# google-resumable-media        1.1.0               2.1.0      wheel
# googleapis-common-protos      1.52.0              1.54.0     wheel
# greenlet                      1.0.0               1.1.2      wheel
# grpcio                        1.42.0              1.43.0     wheel
# h5py                          2.10.0              3.6.0      wheel
# idna                          2.10                3.3        wheel
# imagecodecs                   2021.3.31           2021.11.20 wheel
# imageio                       2.9.0               2.14.1     wheel
# imagesize                     1.2.0               1.3.0      wheel
# imbalanced-learn              0.7.0               0.9.0      wheel
# importlib-metadata            4.8.2               4.10.1     wheel
# install                       1.3.4               1.3.5      wheel
# ipykernel                     6.5.1               6.7.0      wheel
# ipython                       7.30.0              8.0.1      wheel
# ipywidgets                    7.6.3               7.6.5      wheel
# isort                         5.8.0               5.10.1     wheel
# itsdangerous                  1.1.0               2.0.1      wheel
# jedi                          0.17.2              0.18.1     wheel
# Jinja2                        2.11.3              3.0.3      wheel
# joblib                        1.0.1               1.1.0      wheel
# json5                         0.9.5               0.9.6      wheel
# jsonschema                    3.2.0               4.4.0      wheel
# jupyter-client                6.1.12              7.1.2      wheel
# jupyter-core                  4.7.1               4.9.1      wheel
# jupyter-packaging             0.7.12              0.11.1     wheel
# jupyter-server                1.4.1               1.13.4     wheel
# jupyterlab                    3.0.14              3.2.8      wheel
# jupyterlab-server             2.4.0               2.10.3     wheel
# jupyterlab-widgets            1.0.0               1.0.2      wheel
# keras                         2.7.0               2.8.0      wheel
# keyring                       22.3.0              23.5.0     wheel
# kiwisolver                    1.3.1               1.3.2      wheel
# lazy-object-proxy             1.6.0               1.7.1      wheel
# libarchive-c                  2.9                 4.0        wheel
# libclang                      12.0.0              13.0.0     wheel
# llvmlite                      0.36.0              0.38.0     wheel
# lxml                          4.6.3               4.7.1      wheel
# MarkupSafe                    1.1.1               2.0.1      wheel
# matplotlib                    3.3.4               3.5.1      wheel
# mccabe                        0.6.1               0.7.0      wheel
# mistune                       0.8.4               2.0.2      wheel
# mkl-fft                       1.3.0               1.3.1      wheel
# mkl-random                    1.2.1               1.2.2      wheel
# mkl-service                   2.3.0               2.4.0      wheel
# more-itertools                8.7.0               8.12.0     wheel
# msgpack                       1.0.2               1.0.3      wheel
# multidict                     5.1.0               6.0.2      wheel
# nbclassic                     0.2.6               0.3.5      wheel
# nbclient                      0.5.3               0.5.10     wheel
# nbconvert                     6.0.7               6.4.1      wheel
# nest-asyncio                  1.5.1               1.5.4      wheel
# networkx                      2.5                 2.6.3      wheel
# nltk                          3.6.1               3.6.7      wheel
# notebook                      6.3.0               6.4.8      wheel
# numba                         0.53.1              0.55.1     wheel
# numexpr                       2.7.3               2.8.1      wheel
# numpy                         1.20.1              1.22.1     wheel
# numpydoc                      1.1.0               1.2        wheel
# oauthlib                      3.1.1               3.2.0      wheel
# opencv-contrib-python         4.5.4.60            4.5.5.62   wheel
# openpyxl                      3.0.7               3.0.9      wheel
# packaging                     20.9                21.3       wheel
# pandas                        1.2.4               1.4.0      wheel
# pandocfilters                 1.4.3               1.5.0      wheel
# paramiko                      2.7.2               2.9.2      wheel
# parso                         0.7.0               0.8.3      wheel
# path                          15.1.2              16.3.0     wheel
# pathlib2                      2.3.5               2.3.6      wheel
# pathspec                      0.7.0               0.9.0      wheel
# patsy                         0.5.1               0.5.2      wheel
# Pillow                        8.2.0               9.0.0      wheel
# pip                           21.3.1              22.0.2     wheel
# pkginfo                       1.7.0               1.8.2      wheel
# pluggy                        0.13.1              1.0.0      wheel
# prometheus-client             0.10.1              0.13.1     wheel
# prompt-toolkit                3.0.17              3.0.26     wheel
# protobuf                      3.13.0              3.19.4     wheel
# psutil                        5.8.0               5.9.0      wheel
# py                            1.10.0              1.11.0     wheel
# pycodestyle                   2.7.0               2.8.0      wheel
# pycparser                     2.20                2.21       wheel
# pycurl                        7.43.0.6            7.44.1     sdist
# pydocstyle                    6.0.0               6.1.1      wheel
# pyerfa                        1.7.3               2.0.0.1    wheel
# pyflakes                      2.3.1               2.4.0      wheel
# Pygments                      2.8.1               2.11.2     wheel
# pylint                        2.7.4               2.12.2     wheel
# pyls-black                    0.4.6               0.4.7      wheel
# pyls-spyder                   0.3.2               0.4.0      wheel
# PyNaCl                        1.4.0               1.5.0      wheel
# pyodbc                        4.0.0-unsupported   4.0.32     wheel
# pyOpenSSL                     20.0.1              22.0.0     wheel
# pyparsing                     2.4.7               3.0.7      wheel
# pyrsistent                    0.17.3              0.18.1     wheel
# pytest                        6.2.3               6.2.5      wheel
# python-dateutil               2.8.1               2.8.2      wheel
# pytz                          2021.1              2021.3     wheel
# PyWavelets                    1.1.1               1.2.0      wheel
# pywin32                       227                 303        wheel
# pywinpty                      0.5.7               2.0.1      wheel
# PyYAML                        5.4.1               6.0        wheel
# pyzmq                         20.0.0              22.3.0     wheel
# QDarkStyle                    2.8.1               3.0.3      wheel
# QtAwesome                     1.0.2               1.1.1      wheel
# qtconsole                     5.0.3               5.2.2      wheel
# QtPy                          1.9.0               2.0.0      wheel
# regex                         2020.11.13          2022.1.18  wheel
# requests                      2.25.1              2.27.1     wheel
# requests-oauthlib             1.3.0               1.3.1      wheel
# rope                          0.18.0              0.22.0     wheel
# rsa                           4.6                 4.8        wheel
# s3transfer                    0.3.3               0.5.0      wheel
# scikit-image                  0.18.1              0.19.1     wheel
# scikit-learn                  1.0.1               1.0.2      wheel
# scipy                         1.6.2               1.7.3      wheel
# seaborn                       0.11.1              0.11.2     wheel
# Send2Trash                    1.5.0               1.8.0      wheel
# setuptools                    52.0.0.post20210125 60.6.0     wheel
# singledispatch                0.0.0               3.7.0      wheel
# sip                           4.19.13             6.5.1      wheel
# six                           1.15.0              1.16.0     wheel
# smart-open                    3.0.0               5.2.1      wheel
# snowballstemmer               2.1.0               2.2.0      wheel
# sortedcontainers              2.3.0               2.4.0      wheel
# soupsieve                     2.2.1               2.3.1      wheel
# Sphinx                        4.0.1               4.4.0      wheel
# sphinxcontrib-htmlhelp        1.0.3               2.0.0      wheel
# sphinxcontrib-serializinghtml 1.1.4               1.1.5      wheel
# spyder                        4.2.5               5.2.2      wheel
# spyder-kernels                1.10.2              2.2.1      wheel
# SQLAlchemy                    1.4.7               1.4.31     wheel
# statsmodels                   0.12.2              0.13.1     wheel
# sympy                         1.8                 1.9        wheel
# tables                        3.6.1               3.7.0      wheel
# tensorboard                   2.7.0               2.8.0      wheel
# tensorboard-plugin-wit        1.8.0               1.8.1      wheel
# tensorflow-estimator          2.7.0               2.8.0      wheel
# tensorflow-io-gcs-filesystem  0.22.0              0.23.1     wheel
# terminado                     0.9.4               0.13.1     wheel
# testpath                      0.4.4               0.5.0      wheel
# textdistance                  4.2.1               4.2.2      wheel
# threadpoolctl                 2.1.0               3.1.0      wheel
# tifffile                      2021.4.8            2021.11.2  wheel
# toolz                         0.11.1              0.11.2     wheel
# tqdm                          4.59.0              4.62.3     wheel
# typed-ast                     1.4.2               1.5.2      wheel
# typing-extensions             3.7.4.3             4.0.1      wheel
# ujson                         4.0.2               5.1.0      wheel
# urllib3                       1.26.4              1.26.8     wheel
# watchdog                      1.0.2               2.1.6      wheel
# Werkzeug                      1.0.1               2.0.2      wheel
# wheel                         0.36.2              0.37.1     wheel
# widgetsnbextension            3.5.1               3.5.2      wheel
# wrapt                         1.12.1              1.13.3     wheel
# XlsxWriter                    1.3.8               3.0.2      wheel
# xlwings                       0.23.0              0.26.1     sdist
# yapf                          0.31.0              0.32.0     wheel
# yarl                          1.6.3               1.7.2      wheel
# yellowbrick                   0.9.1               1.3.post1  wheel
# zipp                          3.4.1               3.7.0      wheel
# zope.interface                5.3.0               5.4.0      wheel
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importation des jeux de données

# %%
dir_file = 'C:/Users/paul.bonte/Formation OC/P7_Bonte_Paul/data/'

test = pd.read_csv(dir_file + 'application_test.csv')
train = pd.read_csv(dir_file + 'application_train.csv')
bureau = pd.read_csv(dir_file + 'bureau.csv')
bureau_balance = pd.read_csv(dir_file + 'bureau_balance.csv')
cc = pd.read_csv(dir_file + 'credit_card_balance.csv')
instal_paiement = pd.read_csv(dir_file + 'installments_payments.csv')
POS_cash = pd.read_csv(dir_file + 'POS_CASH_balance.csv')

# %%
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48744 entries, 0 to 48743
# Columns: 121 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(40), object(16)
# memory usage: 45.0+ MB
# None

# %%
print(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 122 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(41), object(16)
# memory usage: 286.2+ MB
# None

# %%
print(bureau.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1716428 entries, 0 to 1716427
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   SK_ID_CURR              int64
#  1   SK_ID_BUREAU            int64
#  2   CREDIT_ACTIVE           object
#  3   CREDIT_CURRENCY         object
#  4   DAYS_CREDIT             int64
#  5   CREDIT_DAY_OVERDUE      int64
#  6   DAYS_CREDIT_ENDDATE     float64
#  7   DAYS_ENDDATE_FACT       float64
#  8   AMT_CREDIT_MAX_OVERDUE  float64
#  9   CNT_CREDIT_PROLONG      int64
#  10  AMT_CREDIT_SUM          float64
#  11  AMT_CREDIT_SUM_DEBT     float64
#  12  AMT_CREDIT_SUM_LIMIT    float64
#  13  AMT_CREDIT_SUM_OVERDUE  float64
#  14  CREDIT_TYPE             object
#  15  DAYS_CREDIT_UPDATE      int64
#  16  AMT_ANNUITY             float64
# dtypes: float64(8), int64(6), object(3)
# memory usage: 222.6+ MB
# None

# %%
print(bureau_balance.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27299925 entries, 0 to 27299924
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   SK_ID_BUREAU    int64
#  1   MONTHS_BALANCE  int64
#  2   STATUS          object
# dtypes: int64(2), object(1)
# memory usage: 624.8+ MB
# None

# %%
print(cc.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3840312 entries, 0 to 3840311
# Data columns (total 23 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   SK_ID_PREV                  int64
#  1   SK_ID_CURR                  int64
#  2   MONTHS_BALANCE              int64
#  3   AMT_BALANCE                 float64
#  4   AMT_CREDIT_LIMIT_ACTUAL     int64
#  5   AMT_DRAWINGS_ATM_CURRENT    float64
#  6   AMT_DRAWINGS_CURRENT        float64
#  7   AMT_DRAWINGS_OTHER_CURRENT  float64
#  8   AMT_DRAWINGS_POS_CURRENT    float64
#  9   AMT_INST_MIN_REGULARITY     float64
#  10  AMT_PAYMENT_CURRENT         float64
#  11  AMT_PAYMENT_TOTAL_CURRENT   float64
#  12  AMT_RECEIVABLE_PRINCIPAL    float64
#  13  AMT_RECIVABLE               float64
#  14  AMT_TOTAL_RECEIVABLE        float64
#  15  CNT_DRAWINGS_ATM_CURRENT    float64
#  16  CNT_DRAWINGS_CURRENT        int64
#  17  CNT_DRAWINGS_OTHER_CURRENT  float64
#  18  CNT_DRAWINGS_POS_CURRENT    float64
#  19  CNT_INSTALMENT_MATURE_CUM   float64
#  20  NAME_CONTRACT_STATUS        object
#  21  SK_DPD                      int64
#  22  SK_DPD_DEF                  int64
# dtypes: float64(15), int64(7), object(1)
# memory usage: 673.9+ MB
# None

# %%
print(instal_paiement.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13605401 entries, 0 to 13605400
# Data columns (total 8 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   SK_ID_PREV              int64
#  1   SK_ID_CURR              int64
#  2   NUM_INSTALMENT_VERSION  float64
#  3   NUM_INSTALMENT_NUMBER   int64
#  4   DAYS_INSTALMENT         float64
#  5   DAYS_ENTRY_PAYMENT      float64
#  6   AMT_INSTALMENT          float64
#  7   AMT_PAYMENT             float64
# dtypes: float64(5), int64(3)
# memory usage: 830.4 MB
# None

# %%
print(POS_cash.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001358 entries, 0 to 10001357
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   SK_ID_PREV             int64
#  1   SK_ID_CURR             int64
#  2   MONTHS_BALANCE         int64
#  3   CNT_INSTALMENT         float64
#  4   CNT_INSTALMENT_FUTURE  float64
#  5   NAME_CONTRACT_STATUS   object
#  6   SK_DPD                 int64
#  7   SK_DPD_DEF             int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 610.4+ MB
# None

# %% [markdown]
# # Exploration des données

# %% [markdown]
# ## Check DF utiles

# %%
print("train data: %s rows and %s cols"%train.shape)
print("Credit Card Balance: %s rows and %s cols"%cc.shape)
print("Bureau: %s rows and %s cols"%bureau.shape)
print("Installments Payments: %s rows and %s cols"%instal_paiement.shape)
print("POS_cash: %s rows and %s cols"%POS_cash.shape)
# Out:
# train data: 307511 rows and 122 cols
# Credit Card Balance: 3840312 rows and 23 cols
# Bureau: 1716428 rows and 17 cols
# Installments Payments: 13605401 rows and 8 cols
# POS_cash: 10001358 rows and 8 cols

# %%
print(train.SK_ID_CURR.nunique())
print(cc.SK_ID_CURR.nunique())
print(bureau.SK_ID_CURR.nunique())
print(instal_paiement.SK_ID_CURR.nunique())
print(POS_cash.SK_ID_CURR.nunique())
# Out:
# 307511
# 103558
# 305811
# 339587
# 337252

# %% [markdown]
# ## Analyse exploratoire

# %%
train.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# 50%    5.135310e+05   24903.000000     4.500000e+05
# 75%    8.086500e+05   34596.000000     6.795000e+05
# max    4.050000e+06  258025.500000     4.050000e+06
#
#        REGION_POPULATION_RELATIVE     DAYS_BIRTH  DAYS_EMPLOYED  ...  \
# count               307511.000000  307511.000000  307511.000000  ...
# mean                     0.020868  -16036.995067   63815.045904  ...
# std                      0.013831    4363.988632  141275.766519  ...
# min                      0.000290  -25229.000000  -17912.000000  ...
# 25%                      0.010006  -19682.000000   -2760.000000  ...
# 50%                      0.018850  -15750.000000   -1213.000000  ...
# 75%                      0.028663  -12413.000000    -289.000000  ...
# max                      0.072508   -7489.000000  365243.000000  ...
#
#        FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# count     307511.000000     307511.000000     307511.000000     307511.000000
# mean           0.008130          0.000595          0.000507          0.000335
# std            0.089798          0.024387          0.022518          0.018299
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000          0.000000
# 75%            0.000000          0.000000          0.000000          0.000000
# max            1.000000          1.000000          1.000000          1.000000
#
#        AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# count               265992.000000              265992.000000
# mean                     0.006402                   0.007000
# std                      0.083849                   0.110757
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      4.000000                   9.000000
#
#        AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# count               265992.000000              265992.000000
# mean                     0.034362                   0.267395
# std                      0.204685                   0.916002
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      8.000000                  27.000000
#
#        AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# count              265992.000000               265992.000000
# mean                    0.265474                    1.899974
# std                     0.794056                    1.869295
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    1.000000
# 75%                     0.000000                    3.000000
# max                   261.000000                   25.000000
#
# [8 rows x 106 columns]

# %%
train.hist()
# Out:
# array([[<AxesSubplot:title={'center':'SK_ID_CURR'}>,
#         <AxesSubplot:title={'center':'TARGET'}>,
#         <AxesSubplot:title={'center':'CNT_CHILDREN'}>,
#         <AxesSubplot:title={'center':'AMT_INCOME_TOTAL'}>,
#         <AxesSubplot:title={'center':'AMT_CREDIT'}>,
#         <AxesSubplot:title={'center':'AMT_ANNUITY'}>,
#         <AxesSubplot:title={'center':'AMT_GOODS_PRICE'}>,
#         <AxesSubplot:title={'center':'REGION_POPULATION_RELATIVE'}>,
#         <AxesSubplot:title={'center':'DAYS_BIRTH'}>,
#         <AxesSubplot:title={'center':'DAYS_EMPLOYED'}>],
#        [<AxesSubplot:title={'center':'DAYS_REGISTRATION'}>,
#         <AxesSubplot:title={'center':'DAYS_ID_PUBLISH'}>,
#         <AxesSubplot:title={'center':'OWN_CAR_AGE'}>,
#         <AxesSubplot:title={'center':'FLAG_MOBIL'}>,
#         <AxesSubplot:title={'center':'FLAG_EMP_PHONE'}>,
#         <AxesSubplot:title={'center':'FLAG_WORK_PHONE'}>,
#         <AxesSubplot:title={'center':'FLAG_CONT_MOBILE'}>,
#         <AxesSubplot:title={'center':'FLAG_PHONE'}>,
#         <AxesSubplot:title={'center':'FLAG_EMAIL'}>,
#         <AxesSubplot:title={'center':'CNT_FAM_MEMBERS'}>],
#        [<AxesSubplot:title={'center':'REGION_RATING_CLIENT'}>,
#         <AxesSubplot:title={'center':'REGION_RATING_CLIENT_W_CITY'}>,
#         <AxesSubplot:title={'center':'HOUR_APPR_PROCESS_START'}>,
#         <AxesSubplot:title={'center':'REG_REGION_NOT_LIVE_REGION'}>,
#         <AxesSubplot:title={'center':'REG_REGION_NOT_WORK_REGION'}>,
#         <AxesSubplot:title={'center':'LIVE_REGION_NOT_WORK_REGION'}>,
#         <AxesSubplot:title={'center':'REG_CITY_NOT_LIVE_CITY'}>,
#         <AxesSubplot:title={'center':'REG_CITY_NOT_WORK_CITY'}>,
#         <AxesSubplot:title={'center':'LIVE_CITY_NOT_WORK_CITY'}>,
#         <AxesSubplot:title={'center':'EXT_SOURCE_1'}>],
#        [<AxesSubplot:title={'center':'EXT_SOURCE_2'}>,
#         <AxesSubplot:title={'center':'EXT_SOURCE_3'}>,
#         <AxesSubplot:title={'center':'APARTMENTS_AVG'}>,
#         <AxesSubplot:title={'center':'BASEMENTAREA_AVG'}>,
#         <AxesSubplot:title={'center':'YEARS_BEGINEXPLUATATION_AVG'}>,
#         <AxesSubplot:title={'center':'YEARS_BUILD_AVG'}>,
#         <AxesSubplot:title={'center':'COMMONAREA_AVG'}>,
#         <AxesSubplot:title={'center':'ELEVATORS_AVG'}>,
#         <AxesSubplot:title={'center':'ENTRANCES_AVG'}>,
#         <AxesSubplot:title={'center':'FLOORSMAX_AVG'}>],
#        [<AxesSubplot:title={'center':'FLOORSMIN_AVG'}>,
#         <AxesSubplot:title={'center':'LANDAREA_AVG'}>,
#         <AxesSubplot:title={'center':'LIVINGAPARTMENTS_AVG'}>,
#         <AxesSubplot:title={'center':'LIVINGAREA_AVG'}>,
#         <AxesSubplot:title={'center':'NONLIVINGAPARTMENTS_AVG'}>,
#         <AxesSubplot:title={'center':'NONLIVINGAREA_AVG'}>,
#         <AxesSubplot:title={'center':'APARTMENTS_MODE'}>,
#         <AxesSubplot:title={'center':'BASEMENTAREA_MODE'}>,
#         <AxesSubplot:title={'center':'YEARS_BEGINEXPLUATATION_MODE'}>,
#         <AxesSubplot:title={'center':'YEARS_BUILD_MODE'}>],
#        [<AxesSubplot:title={'center':'COMMONAREA_MODE'}>,
#         <AxesSubplot:title={'center':'ELEVATORS_MODE'}>,
#         <AxesSubplot:title={'center':'ENTRANCES_MODE'}>,
#         <AxesSubplot:title={'center':'FLOORSMAX_MODE'}>,
#         <AxesSubplot:title={'center':'FLOORSMIN_MODE'}>,
#         <AxesSubplot:title={'center':'LANDAREA_MODE'}>,
#         <AxesSubplot:title={'center':'LIVINGAPARTMENTS_MODE'}>,
#         <AxesSubplot:title={'center':'LIVINGAREA_MODE'}>,
#         <AxesSubplot:title={'center':'NONLIVINGAPARTMENTS_MODE'}>,
#         <AxesSubplot:title={'center':'NONLIVINGAREA_MODE'}>],
#        [<AxesSubplot:title={'center':'APARTMENTS_MEDI'}>,
#         <AxesSubplot:title={'center':'BASEMENTAREA_MEDI'}>,
#         <AxesSubplot:title={'center':'YEARS_BEGINEXPLUATATION_MEDI'}>,
#         <AxesSubplot:title={'center':'YEARS_BUILD_MEDI'}>,
#         <AxesSubplot:title={'center':'COMMONAREA_MEDI'}>,
#         <AxesSubplot:title={'center':'ELEVATORS_MEDI'}>,
#         <AxesSubplot:title={'center':'ENTRANCES_MEDI'}>,
#         <AxesSubplot:title={'center':'FLOORSMAX_MEDI'}>,
#         <AxesSubplot:title={'center':'FLOORSMIN_MEDI'}>,
#         <AxesSubplot:title={'center':'LANDAREA_MEDI'}>],
#        [<AxesSubplot:title={'center':'LIVINGAPARTMENTS_MEDI'}>,
#         <AxesSubplot:title={'center':'LIVINGAREA_MEDI'}>,
#         <AxesSubplot:title={'center':'NONLIVINGAPARTMENTS_MEDI'}>,
#         <AxesSubplot:title={'center':'NONLIVINGAREA_MEDI'}>,
#         <AxesSubplot:title={'center':'TOTALAREA_MODE'}>,
#         <AxesSubplot:title={'center':'OBS_30_CNT_SOCIAL_CIRCLE'}>,
#         <AxesSubplot:title={'center':'DEF_30_CNT_SOCIAL_CIRCLE'}>,
#         <AxesSubplot:title={'center':'OBS_60_CNT_SOCIAL_CIRCLE'}>,
#         <AxesSubplot:title={'center':'DEF_60_CNT_SOCIAL_CIRCLE'}>,
#         <AxesSubplot:title={'center':'DAYS_LAST_PHONE_CHANGE'}>],
#        [<AxesSubplot:title={'center':'FLAG_DOCUMENT_2'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_3'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_4'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_5'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_6'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_7'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_8'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_9'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_10'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_11'}>],
#        [<AxesSubplot:title={'center':'FLAG_DOCUMENT_12'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_13'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_14'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_15'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_16'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_17'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_18'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_19'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_20'}>,
#         <AxesSubplot:title={'center':'FLAG_DOCUMENT_21'}>],
#        [<AxesSubplot:title={'center':'AMT_REQ_CREDIT_BUREAU_HOUR'}>,
#         <AxesSubplot:title={'center':'AMT_REQ_CREDIT_BUREAU_DAY'}>,
#         <AxesSubplot:title={'center':'AMT_REQ_CREDIT_BUREAU_WEEK'}>,
#         <AxesSubplot:title={'center':'AMT_REQ_CREDIT_BUREAU_MON'}>,
#         <AxesSubplot:title={'center':'AMT_REQ_CREDIT_BUREAU_QRT'}>,
#         <AxesSubplot:title={'center':'AMT_REQ_CREDIT_BUREAU_YEAR'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %%
for col in train.columns:
    if train[col].dtype == 'object':
        print("object column %s have %s unique values"%(str(col),train[col].nunique()))
        if train[col].nunique() <= 3:
            print(train[col].value_counts())
            print('-------------')
        else:
            ax = sns.catplot(x=col, kind="count", data=train,height=6, aspect=2.2)
            for axes in ax.axes.flat:
                axes.set_xticklabels(axes.get_xticklabels(),rotation = 45,horizontalalignment = 'right')
# Out:
# object column NAME_CONTRACT_TYPE have 2 unique values
# Cash loans         278232
# Revolving loans     29279
# Name: NAME_CONTRACT_TYPE, dtype: int64
# -------------
# object column CODE_GENDER have 3 unique values
# F      202448
# M      105059
# XNA         4
# Name: CODE_GENDER, dtype: int64
# -------------
# object column FLAG_OWN_CAR have 2 unique values
# N    202924
# Y    104587
# Name: FLAG_OWN_CAR, dtype: int64
# -------------
# object column FLAG_OWN_REALTY have 2 unique values
# Y    213312
# N     94199
# Name: FLAG_OWN_REALTY, dtype: int64
# -------------
# object column NAME_TYPE_SUITE have 7 unique values
# object column NAME_INCOME_TYPE have 8 unique values
# object column NAME_EDUCATION_TYPE have 5 unique values
# object column NAME_FAMILY_STATUS have 6 unique values
# object column NAME_HOUSING_TYPE have 6 unique values
# object column OCCUPATION_TYPE have 18 unique values
# object column WEEKDAY_APPR_PROCESS_START have 7 unique values
# object column ORGANIZATION_TYPE have 58 unique values
# object column FONDKAPREMONT_MODE have 4 unique values
# object column HOUSETYPE_MODE have 3 unique values
# block of flats      150503
# specific housing      1499
# terraced house        1212
# Name: HOUSETYPE_MODE, dtype: int64
# -------------
# object column WALLSMATERIAL_MODE have 7 unique values
# object column EMERGENCYSTATE_MODE have 2 unique values
# No     159428
# Yes      2328
# Name: EMERGENCYSTATE_MODE, dtype: int64
# -------------

# %%
cc.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR  MONTHS_BALANCE   AMT_BALANCE  \
# count  3.840312e+06  3.840312e+06    3.840312e+06  3.840312e+06
# mean   1.904504e+06  2.783242e+05   -3.452192e+01  5.830016e+04
# std    5.364695e+05  1.027045e+05    2.666775e+01  1.063070e+05
# min    1.000018e+06  1.000060e+05   -9.600000e+01 -4.202502e+05
# 25%    1.434385e+06  1.895170e+05   -5.500000e+01  0.000000e+00
# 50%    1.897122e+06  2.783960e+05   -2.800000e+01  0.000000e+00
# 75%    2.369328e+06  3.675800e+05   -1.100000e+01  8.904669e+04
# max    2.843496e+06  4.562500e+05   -1.000000e+00  1.505902e+06
#
#        AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# count             3.840312e+06              3.090496e+06
# mean              1.538080e+05              5.961325e+03
# std               1.651457e+05              2.822569e+04
# min               0.000000e+00             -6.827310e+03
# 25%               4.500000e+04              0.000000e+00
# 50%               1.125000e+05              0.000000e+00
# 75%               1.800000e+05              0.000000e+00
# max               1.350000e+06              2.115000e+06
#
#        AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# count          3.840312e+06                3.090496e+06
# mean           7.433388e+03                2.881696e+02
# std            3.384608e+04                8.201989e+03
# min           -6.211620e+03                0.000000e+00
# 25%            0.000000e+00                0.000000e+00
# 50%            0.000000e+00                0.000000e+00
# 75%            0.000000e+00                0.000000e+00
# max            2.287098e+06                1.529847e+06
#
#        AMT_DRAWINGS_POS_CURRENT  AMT_INST_MIN_REGULARITY  ...  \
# count              3.090496e+06             3.535076e+06  ...
# mean               2.968805e+03             3.540204e+03  ...
# std                2.079689e+04             5.600154e+03  ...
# min                0.000000e+00             0.000000e+00  ...
# 25%                0.000000e+00             0.000000e+00  ...
# 50%                0.000000e+00             0.000000e+00  ...
# 75%                0.000000e+00             6.633911e+03  ...
# max                2.239274e+06             2.028820e+05  ...
#
#        AMT_RECEIVABLE_PRINCIPAL  AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  \
# count              3.840312e+06   3.840312e+06          3.840312e+06
# mean               5.596588e+04   5.808881e+04          5.809829e+04
# std                1.025336e+05   1.059654e+05          1.059718e+05
# min               -4.233058e+05  -4.202502e+05         -4.202502e+05
# 25%                0.000000e+00   0.000000e+00          0.000000e+00
# 50%                0.000000e+00   0.000000e+00          0.000000e+00
# 75%                8.535924e+04   8.889949e+04          8.891451e+04
# max                1.472317e+06   1.493338e+06          1.493338e+06
#
#        CNT_DRAWINGS_ATM_CURRENT  CNT_DRAWINGS_CURRENT  \
# count              3.090496e+06          3.840312e+06
# mean               3.094490e-01          7.031439e-01
# std                1.100401e+00          3.190347e+00
# min                0.000000e+00          0.000000e+00
# 25%                0.000000e+00          0.000000e+00
# 50%                0.000000e+00          0.000000e+00
# 75%                0.000000e+00          0.000000e+00
# max                5.100000e+01          1.650000e+02
#
#        CNT_DRAWINGS_OTHER_CURRENT  CNT_DRAWINGS_POS_CURRENT  \
# count                3.090496e+06              3.090496e+06
# mean                 4.812496e-03              5.594791e-01
# std                  8.263861e-02              3.240649e+00
# min                  0.000000e+00              0.000000e+00
# 25%                  0.000000e+00              0.000000e+00
# 50%                  0.000000e+00              0.000000e+00
# 75%                  0.000000e+00              0.000000e+00
# max                  1.200000e+01              1.650000e+02
#
#        CNT_INSTALMENT_MATURE_CUM        SK_DPD    SK_DPD_DEF
# count               3.535076e+06  3.840312e+06  3.840312e+06
# mean                2.082508e+01  9.283667e+00  3.316220e-01
# std                 2.005149e+01  9.751570e+01  2.147923e+01
# min                 0.000000e+00  0.000000e+00  0.000000e+00
# 25%                 4.000000e+00  0.000000e+00  0.000000e+00
# 50%                 1.500000e+01  0.000000e+00  0.000000e+00
# 75%                 3.200000e+01  0.000000e+00  0.000000e+00
# max                 1.200000e+02  3.260000e+03  3.260000e+03
#
# [8 rows x 22 columns]

# %%
bureau.describe()
# Out:
#          SK_ID_CURR  SK_ID_BUREAU   DAYS_CREDIT  CREDIT_DAY_OVERDUE  \
# count  1.716428e+06  1.716428e+06  1.716428e+06        1.716428e+06
# mean   2.782149e+05  5.924434e+06 -1.142108e+03        8.181666e-01
# std    1.029386e+05  5.322657e+05  7.951649e+02        3.654443e+01
# min    1.000010e+05  5.000000e+06 -2.922000e+03        0.000000e+00
# 25%    1.888668e+05  5.463954e+06 -1.666000e+03        0.000000e+00
# 50%    2.780550e+05  5.926304e+06 -9.870000e+02        0.000000e+00
# 75%    3.674260e+05  6.385681e+06 -4.740000e+02        0.000000e+00
# max    4.562550e+05  6.843457e+06  0.000000e+00        2.792000e+03
#
#        DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  AMT_CREDIT_MAX_OVERDUE  \
# count         1.610875e+06       1.082775e+06            5.919400e+05
# mean          5.105174e+02      -1.017437e+03            3.825418e+03
# std           4.994220e+03       7.140106e+02            2.060316e+05
# min          -4.206000e+04      -4.202300e+04            0.000000e+00
# 25%          -1.138000e+03      -1.489000e+03            0.000000e+00
# 50%          -3.300000e+02      -8.970000e+02            0.000000e+00
# 75%           4.740000e+02      -4.250000e+02            0.000000e+00
# max           3.119900e+04       0.000000e+00            1.159872e+08
#
#        CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  AMT_CREDIT_SUM_DEBT  \
# count        1.716428e+06    1.716415e+06         1.458759e+06
# mean         6.410406e-03    3.549946e+05         1.370851e+05
# std          9.622391e-02    1.149811e+06         6.774011e+05
# min          0.000000e+00    0.000000e+00        -4.705600e+06
# 25%          0.000000e+00    5.130000e+04         0.000000e+00
# 50%          0.000000e+00    1.255185e+05         0.000000e+00
# 75%          0.000000e+00    3.150000e+05         4.015350e+04
# max          9.000000e+00    5.850000e+08         1.701000e+08
#
#        AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  DAYS_CREDIT_UPDATE  \
# count          1.124648e+06            1.716428e+06        1.716428e+06
# mean           6.229515e+03            3.791276e+01       -5.937483e+02
# std            4.503203e+04            5.937650e+03        7.207473e+02
# min           -5.864061e+05            0.000000e+00       -4.194700e+04
# 25%            0.000000e+00            0.000000e+00       -9.080000e+02
# 50%            0.000000e+00            0.000000e+00       -3.950000e+02
# 75%            0.000000e+00            0.000000e+00       -3.300000e+01
# max            4.705600e+06            3.756681e+06        3.720000e+02
#
#         AMT_ANNUITY
# count  4.896370e+05
# mean   1.571276e+04
# std    3.258269e+05
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.350000e+04
# max    1.184534e+08

# %%
instal_paiement.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# count  1.360540e+07  1.360540e+07            1.360540e+07
# mean   1.903365e+06  2.784449e+05            8.566373e-01
# std    5.362029e+05  1.027183e+05            1.035216e+00
# min    1.000001e+06  1.000010e+05            0.000000e+00
# 25%    1.434191e+06  1.896390e+05            0.000000e+00
# 50%    1.896520e+06  2.786850e+05            1.000000e+00
# 75%    2.369094e+06  3.675300e+05            1.000000e+00
# max    2.843499e+06  4.562550e+05            1.780000e+02
#
#        NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# count           1.360540e+07     1.360540e+07        1.360250e+07
# mean            1.887090e+01    -1.042270e+03       -1.051114e+03
# std             2.666407e+01     8.009463e+02        8.005859e+02
# min             1.000000e+00    -2.922000e+03       -4.921000e+03
# 25%             4.000000e+00    -1.654000e+03       -1.662000e+03
# 50%             8.000000e+00    -8.180000e+02       -8.270000e+02
# 75%             1.900000e+01    -3.610000e+02       -3.700000e+02
# max             2.770000e+02    -1.000000e+00       -1.000000e+00
#
#        AMT_INSTALMENT   AMT_PAYMENT
# count    1.360540e+07  1.360250e+07
# mean     1.705091e+04  1.723822e+04
# std      5.057025e+04  5.473578e+04
# min      0.000000e+00  0.000000e+00
# 25%      4.226085e+03  3.398265e+03
# 50%      8.884080e+03  8.125515e+03
# 75%      1.671021e+04  1.610842e+04
# max      3.771488e+06  3.771488e+06

# %%
POS_cash.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# count  1.000136e+07  1.000136e+07    1.000136e+07    9.975287e+06
# mean   1.903217e+06  2.784039e+05   -3.501259e+01    1.708965e+01
# std    5.358465e+05  1.027637e+05    2.606657e+01    1.199506e+01
# min    1.000001e+06  1.000010e+05   -9.600000e+01    1.000000e+00
# 25%    1.434405e+06  1.895500e+05   -5.400000e+01    1.000000e+01
# 50%    1.896565e+06  2.786540e+05   -2.800000e+01    1.200000e+01
# 75%    2.368963e+06  3.674290e+05   -1.300000e+01    2.400000e+01
# max    2.843499e+06  4.562550e+05   -1.000000e+00    9.200000e+01
#
#        CNT_INSTALMENT_FUTURE        SK_DPD    SK_DPD_DEF
# count           9.975271e+06  1.000136e+07  1.000136e+07
# mean            1.048384e+01  1.160693e+01  6.544684e-01
# std             1.110906e+01  1.327140e+02  3.276249e+01
# min             0.000000e+00  0.000000e+00  0.000000e+00
# 25%             3.000000e+00  0.000000e+00  0.000000e+00
# 50%             7.000000e+00  0.000000e+00  0.000000e+00
# 75%             1.400000e+01  0.000000e+00  0.000000e+00
# max             8.500000e+01  4.231000e+03  3.595000e+03

# %% [markdown]
# ### données manquantes

# %%
# Ajouter dans une variable un dataframe comprenant le % de valeur manquante par colonne
Nb_missing = pd.DataFrame(train.isna().sum()/train.shape[0]*100)
Nb_missing.columns = ["p_missing"]
Nb_missing.sort_values(ascending = False, by = 'p_missing', inplace=True)

# Représentation graphique
fig1 = sns.barplot(x = Nb_missing.index, y = "p_missing" , data = Nb_missing)
sns.set(rc={'figure.figsize':(20,15)})
plt.xticks(rotation=90)
print(fig1)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
train = train[train.columns[train.isnull().mean() < 0.5]]

# %%
# Ajouter dans une variable un dataframe comprenant le % de valeur manquante par colonne
Nb_missing = pd.DataFrame(train.isna().sum()/train.shape[0]*100)
Nb_missing.columns = ["p_missing"]
Nb_missing.sort_values(ascending = False, by = 'p_missing', inplace=True)

# Représentation graphique
fig1 = sns.barplot(x = Nb_missing.index, y = "p_missing" , data = Nb_missing)
sns.set(rc={'figure.figsize':(20,15)})
plt.xticks(rotation=90)
print(fig1)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# Ajouter dans une variable un dataframe comprenant le % de valeur manquante par colonne
Nb_missing = pd.DataFrame(cc.isna().sum()/cc.shape[0]*100)
Nb_missing.columns = ["p_missing"]
Nb_missing.sort_values(ascending = False, by = 'p_missing', inplace=True)

# Représentation graphique
fig1 = sns.barplot(x = Nb_missing.index, y = "p_missing" , data = Nb_missing)
sns.set(rc={'figure.figsize':(20,15)})
plt.xticks(rotation=90)
print(fig1)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# Ajouter dans une variable un dataframe comprenant le % de valeur manquante par colonne
Nb_missing = pd.DataFrame(bureau.isna().sum()/bureau.shape[0]*100)
Nb_missing.columns = ["p_missing"]
Nb_missing.sort_values(ascending = False, by = 'p_missing', inplace=True)

# Représentation graphique
fig1 = sns.barplot(x = Nb_missing.index, y = "p_missing" , data = Nb_missing)
sns.set(rc={'figure.figsize':(20,15)})
plt.xticks(rotation=90)
print(fig1)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
bureau = bureau[bureau.columns[bureau.isnull().mean() < 0.5]]

# %%
# Ajouter dans une variable un dataframe comprenant le % de valeur manquante par colonne
Nb_missing = pd.DataFrame(instal_paiement.isna().sum()/instal_paiement.shape[0]*100)
Nb_missing.columns = ["p_missing"]
Nb_missing.sort_values(ascending = False, by = 'p_missing', inplace=True)

# Représentation graphique
fig1 = sns.barplot(x = Nb_missing.index, y = "p_missing" , data = Nb_missing)
sns.set(rc={'figure.figsize':(20,15)})
plt.xticks(rotation=90)
print(fig1)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# Ajouter dans une variable un dataframe comprenant le % de valeur manquante par colonne
Nb_missing = pd.DataFrame(POS_cash.isna().sum()/POS_cash.shape[0]*100)
Nb_missing.columns = ["p_missing"]
Nb_missing.sort_values(ascending = False, by = 'p_missing', inplace=True)

# Représentation graphique
fig1 = sns.barplot(x = Nb_missing.index, y = "p_missing" , data = Nb_missing)
sns.set(rc={'figure.figsize':(20,15)})
plt.xticks(rotation=90)
print(fig1)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ### Target

# %%
train.TARGET.value_counts(normalize= True)
# Out:
# 0    0.919271
# 1    0.080729
# Name: TARGET, dtype: float64

# %%
train['TARGET'].plot.hist(title = 'target var: default indicator')
sns.set(rc={'figure.figsize':(4,8)})

# %%
mat_corr = train.corr()
fig, ax = plt.subplots(figsize=(20,20))
ax = sns.heatmap(abs(mat_corr) , annot = True , cmap = 'coolwarm')
ax.set_yticklabels(ax.get_ymajorticklabels(), fontsize = 18)
ax.set_xticklabels(ax.get_xmajorticklabels(), fontsize = 18)
ax
# Out:
# <AxesSubplot:>

# %%
correlations = train.corr()['TARGET'].sort_values()
print('Most Positive Correlations:\n', correlations.tail(8))
print('\nMost Negative Correlations:\n', correlations.head(8))

# %% [markdown]
# ## Viz des données corrélés à target

# %%
pos_corr = correlations.tail(8)
df_pos = train[pos_corr.index]
df_pos.hist()

# %%
neg_corr = correlations.tail(8)
df_pos = train[neg_corr.index]
df_pos.hist()

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Création des features

# %%
# Feature Engineering and extract attributes for use from Credit Card Balance & Installments Payments
cc['AMT_DRAWINGS_PCT'] = [x/y if (y != 0) & pd.notnull(y) else np.nan for x,y in zip(cc.AMT_DRAWINGS_CURRENT,cc.AMT_CREDIT_LIMIT_ACTUAL)]
cc['AMT_DRAWINGS_ATM_PCT'] = [x/y if (y != 0) & pd.notnull(y) else np.nan for x,y in zip(cc.AMT_DRAWINGS_ATM_CURRENT,cc.AMT_CREDIT_LIMIT_ACTUAL)]
cc['AMT_DRAWINGS_OTHER_PCT'] = [x/y if (y != 0) & pd.notnull(y) else np.nan for x,y in zip(cc.AMT_DRAWINGS_OTHER_CURRENT,cc.AMT_CREDIT_LIMIT_ACTUAL)]
cc['AMT_DRAWINGS_POS_PCT'] = [x/y if (y != 0) & pd.notnull(y) else np.nan for x,y in zip(cc.AMT_DRAWINGS_POS_CURRENT,cc.AMT_CREDIT_LIMIT_ACTUAL)]

cc['AMT_PRINCIPAL_RECEIVABLE_PCT'] = [x/y if (y != 0) & pd.notnull(y) else np.nan for x,y in zip(cc.AMT_RECEIVABLE_PRINCIPAL,cc.AMT_RECIVABLE)]

cc_use = cc.groupby(['SK_ID_CURR'],as_index=False).agg({'AMT_BALANCE': np.mean,
                                                        'AMT_DRAWINGS_PCT':np.mean,
                                                        'AMT_DRAWINGS_ATM_PCT':np.mean,
                                                        'AMT_DRAWINGS_OTHER_PCT':np.mean,
                                                        'AMT_DRAWINGS_POS_PCT':np.mean,
                                                        'AMT_PRINCIPAL_RECEIVABLE_PCT':np.mean,
                                                        'CNT_DRAWINGS_ATM_CURRENT':np.mean,
                                                        'CNT_DRAWINGS_CURRENT':np.mean,
                                                        'CNT_DRAWINGS_OTHER_CURRENT':np.mean,
                                                        'CNT_DRAWINGS_POS_CURRENT':np.mean,
                                                        'SK_DPD':np.mean,
                                                        'SK_DPD_DEF':np.mean})
instal_paiement['DAYS_INSTALMENT_DIFF'] = instal_paiement['DAYS_INSTALMENT'] - instal_paiement['DAYS_ENTRY_PAYMENT']
instal_paiement['AMT_PATMENT_PCT'] = [x/y if (y != 0) & pd.notnull(y) else np.nan for x,y in zip(instal_paiement.AMT_PAYMENT,instal_paiement.AMT_INSTALMENT)]
pmts_use = instal_paiement.groupby(['SK_ID_CURR'],as_index=False).agg({'DAYS_INSTALMENT_DIFF':np.mean,
                                                            'AMT_PATMENT_PCT':np.mean})

# %%
# Merge Credit Card Balance & Installment Payments
train = train.merge(cc_use,on='SK_ID_CURR',how='left')
train = train.merge(pmts_use,on='SK_ID_CURR',how='left')

# %%
# One-hot encoding for categorical variable
cat_cols = [key for key in dict(train.dtypes) if dict(train.dtypes)[key] in ['object']]
cat_cols_df = pd.get_dummies(train[cat_cols],drop_first=True)
train = pd.concat([cat_cols_df,train[train.columns[~train.columns.isin(cat_cols)]]], axis = 1)

# print(train_use.shape)
train = train[train.columns[~train.columns.isin(cat_cols)]]

# Remove ID column
train = train.drop(['SK_ID_CURR'],axis=1).reset_index(drop=True)
train.replace([np.inf, -np.inf], np.nan, inplace=True)

train.shape

# %% [markdown]
# ### Exploration des features

# %% [markdown]
# # Simple Imputer

# %%
y_columns = ['TARGET']
X = train.drop(y_columns, axis=1)
print(X.shape)
y = train[y_columns]
print(y.shape)

# %%
# Simple imputer
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
X_imp = imputer.fit_transform(X)

# %%
X_imp.shape

# %% [markdown]
# # Modélisation

# %% [markdown]
# ## Equilibrage des classes

# %%
from imblearn.over_sampling import SMOTE

# %%
y.shape

# %%
smt = SMOTE()
X_resize , y_resize = smt.fit_resample(X_imp,y)

# %%
y_resize.shape

# %% [markdown]
# ## Baseline

# %%
from sklearn import dummy

# %%
my_dummy = dummy.DummyClassifier(strategy = 'most_frequent')

# %%
my_dummy.fit(X = X, y = y)

# %%
y_prob_dummy = (my_dummy.predict_proba(train)[:,1]).astype('float16')

# %%
from sklearn import metrics

# %%
fpr_dummy, tpr_dummy, th_dummy = metrics.roc_curve(train.TARGET, y_prob_dummy)
roc_auc_dummy = metrics.auc(fpr_dummy, tpr_dummy)
print(roc_auc_dummy)

# %%
plt.plot(fpr_dummy, tpr_dummy ,linestyle='--', label = "Dummy AUC %0.2f" % roc_auc_dummy)

# %%
cm = metrics.confusion_matrix(y_true=train.TARGET, y_pred = (y_prob_dummy >= 0.5).astype(int) )
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm)
sns.set(rc={'figure.figsize':(4,8)})
disp.plot()

# %%
cm

# %% [markdown]
# ## Régression Logistique

# %% [markdown]
# ### Imbalanced

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X, y.values)

# %%
y_prob_log = (log_reg.predict_proba(X)[:,1]).astype('float16')

# %%
sns.histplot(y_prob_log)

# %%
fpr_log, tpr_log, th_log = metrics.roc_curve(y, y_prob_log)
roc_auc_log = metrics.auc(fpr_log, tpr_log)
print(roc_auc_log)

# %%
plt.plot(fpr_log, tpr_log ,linestyle='--', label = "Log_grid AUC %0.2f" % roc_auc_log)
plt.plot(fpr_dummy, tpr_dummy ,linestyle='-', label = "Dummy AUC %0.2f" % roc_auc_dummy)

# %% [markdown]
# #### Recherche sur grille

# %%
param_grid_log_reg = {'C': [0.01, 0.1, 1, 10, 100] ,'penalty':['l1','l2']}
grid_log_reg=GridSearchCV(LogisticRegression(),param_grid_log_reg,verbose = False, cv =5)
grid_log_reg.fit(X,y)

# %%
print(grid_log_reg.best_params_)

# %%
y_prob_log_grid = (grid_log_reg.predict_proba(X)[:,1]).astype('float16')

# %%
sns.histplot(y_prob_log_grid)

# %%
fpr_log_grid, tpr_log_grid, th_log_grid = metrics.roc_curve(y, y_prob_log_grid)
roc_auc_log_grid = metrics.auc(fpr_log_grid, tpr_log_grid)
print(roc_auc_log_grid)

# %%
plt.plot(fpr_log_grid, tpr_log_grid ,linestyle='--', label = "Log_grid AUC %0.2f" % roc_auc_log)
plt.plot(fpr_dummy, tpr_dummy ,linestyle='-', label = "Dummy AUC %0.2f" % roc_auc_dummy)

# %%
cm = metrics.confusion_matrix(y_true=y, y_pred = (y_prob_log_grid >= 0.6).astype(int) )
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm)
sns.set(rc={'figure.figsize':(4,8)})
disp.plot()

# %% [markdown]
# ### Balanced

# %%
log_reg.fit(X_resize, y_resize)

# %%
y_prob_log = (log_reg.predict_proba(X_resize)[:,1]).astype('float16')

# %%
sns.histplot(y_prob_log)

# %%
fpr_log, tpr_log, th_log = metrics.roc_curve(y_resize, y_prob_log)
roc_auc_log = metrics.auc(fpr_log, tpr_log)
print(roc_auc_log)

# %%
plt.plot(fpr_log, tpr_log ,linestyle='--', label = "Log_grid AUC %0.2f" % roc_auc_log)
plt.plot(fpr_dummy, tpr_dummy ,linestyle='-', label = "Dummy AUC %0.2f" % roc_auc_dummy)

# %%
cm = metrics.confusion_matrix(y_true=y, y_pred = (y_prob_log >= 0.5).astype(int) )
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm)
sns.set(rc={'figure.figsize':(4,8)})
disp.plot()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 100, max_features=5)
rf.fit(X_resize, y_resize)

# %%
y_prob_rf = (rf.predict_proba(X)[:,1]).astype('float16')

# %%
sns.histplot(y_prob_rf)

# %%
fpr_rf, tpr_rf, th_rf = metrics.roc_curve(y, y_prob_rf)
roc_auc_rf = metrics.auc(fpr_rf, tpr_rf)
print(roc_auc_rf)

# %%
plt.plot(fpr_rf, tpr_rf ,linestyle='--', label = "RF_grid AUC %0.2f" % roc_auc_rf)
plt.plot(fpr_rf, tpr_rf ,linestyle='-', label = "Dummy AUC %0.2f" % roc_auc_dummy)

# %%
cm = metrics.confusion_matrix(y_true=y, y_pred = (y_prob_rf >= 0.6).astype(int) )
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm)
sns.set(rc={'figure.figsize':(4,8)})
disp.plot()

# %% [markdown]
# ## GBT

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbt = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
gbt.fit(X_resize, y_resize)

# %%
y_prob_gbt = (gbt.predict_proba(X)[:,1]).astype('float16')

# %%
sns.histplot(y_prob_gbt)

# %%
fpr_gbt, tpr_gbt, th_gbt = metrics.roc_curve(y, y_prob_gbt)
roc_auc_gbt = metrics.auc(fpr_gbt, tpr_gbt)
print(roc_auc_rf)

# %%
plt.plot(fpr_gbt, tpr_gbt ,linestyle='--', label = "GBT_grid AUC %0.2f" % roc_auc_rf)
plt.plot(fpr_rf, tpr_rf ,linestyle='-', label = "Dummy AUC %0.2f" % roc_auc_dummy)

# %%
cm = metrics.confusion_matrix(y_true=y, y_pred = (y_prob_gbt >= 0.6).astype(int) )
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm)
sns.set(rc={'figure.figsize':(4,8)})
disp.plot()

# %%
# Lime et shaply pour comprendre comment le modèle fait pour attribuer un score interpretabilité local ou global (feature importance) puis lime shaply
